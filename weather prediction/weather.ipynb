# %%
#Weather predictions project

import pandas as pd

weather = pd.read_csv("weather.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                              NAME  ACMH   ACSH   AWND  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0    NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0    NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0    NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0    NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0    NaN
# ...                 ...                               ...   ...    ...    ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN   9.62
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  12.08
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  14.99
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  16.78
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN    NaN
#
# ...

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.501478
# ACSH       0.501426
# AWND       0.265256
# FMTM       0.475087
# PGTM       0.363872
# PRCP       0.000000
# SNOW       0.000000
# SNWD       0.000104
# TAVG       0.680406
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.998393
# WDF1       0.501685
# WDF2       0.498678
# WDF5       0.502981
# WDFG       0.734484
# WDFM       0.999948
# WESD       0.685228
# WSF1       0.501530
# WSF2       0.498678
# WSF5       0.503033
# WSFG       0.613055
# WSFM       0.999948
# WT01       0.630217
# WT02       0.935034
# WT03       0.933271
# WT04       0.982579
# WT05       0.981127
# WT06       0.990615
# WT07       0.994400
# WT08       0.796962
# WT09       0.992741
# WT11       0.999274
# WT13       0.886711
# WT14       0.954010
# WT15       0.997822
# WT16       0.658993
# WT17       0.996889
# WT18       0.939493
# WT21       0.999741
# WT22       0.997459
# WV01       0.999948
# dtype: float64

# %%
weather = weather[["PRCP", "SNOW", "SNWD", "TMAX", "TMIN"]].copy()
weather.columns = ["precip", "snow", "snow_depth", "temp_max", "temp_min"]

# %%
weather.apply(pd.isnull).sum()
# Out:
# precip        0
# snow          0
# snow_depth    2
# temp_max      0
# temp_min      0
# dtype: int64

# %%
weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1970-01-01    0.00   0.0         0.0        28        22
# 1970-01-02    0.00   0.0         0.0        31        22
# 1970-01-03    0.02   0.0         0.0        38        25
# 1970-01-04    0.00   0.0         0.0        31        23
# 1970-01-05    0.00   0.0         0.0        35        21
# ...            ...   ...         ...       ...       ...
# 2022-10-17    0.08   0.0         0.0        67        54
# 2022-10-18    0.00   0.0         0.0        58        48
# 2022-10-19    0.00   0.0         0.0        56        43
# 2022-10-20    0.00   0.0         0.0        61        44
# 2022-10-21    0.00   0.0         0.0        64        43
#
# [19287 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# ...

# %%
weather["snow_depth"].value_counts()
# Out:
# 0.0     18313
# 1.0       223
# 2.0       189
# 3.0        98
# 4.0        61
# 1.2        50
# 6.0        46
# 5.0        44
# 7.0        27
# 8.0        26
# 5.1        21
# 9.0        18
# 3.1        17
# 7.1        17
# 11.0       15
# 10.0       13
# 3.9        13
# 5.9        13
# 7.9        12
# 9.1        11
# 12.0       11
# 14.0        9
# 9.8         8
# 13.0        5
# 17.0        4
# 19.0        3
# 16.0        3
# 22.0        3
# 15.0        2
# 26.0        2
# 28.0        2
# 18.0        2
# 21.0        2
# 23.0        1
# 11.8        1
# Name: snow_depth, dtype: int64

# %%
del weather["snow"]

# %%
del weather["snow_depth"]

# %%
weather[pd.isnull(weather["precip"])]
# Out:
# Empty DataFrame
# Columns: [precip, temp_max, temp_min]
# Index: []
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
# ...

# %%
weather.loc["2013-12-15",:]
# Out:
# precip       0.82
# temp_max    47.00
# temp_min    33.00
# Name: 2013-12-15, dtype: float64

# %%
weather["precip"].value_counts() / weather.shape[0]
# Out:
# 0.00    0.671955
# 0.01    0.030072
# 0.02    0.021206
# 0.03    0.015347
# 0.04    0.013066
#           ...
# 2.81    0.000052
# 3.92    0.000052
# 2.70    0.000052
# 2.18    0.000052
# 3.24    0.000052
# Name: precip, Length: 271, dtype: float64

# %%
weather["precip"] = weather["precip"].fillna(0)

# %%
weather.apply(pd.isnull).sum()
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
weather[pd.isnull(weather["temp_min"])]
# Out:
# Empty DataFrame
# Columns: [precip, temp_max, temp_min]
# Index: []
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
# ...

# %%
weather.loc["2011-12-18":"2011-12-28"]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2011-12-18    0.00        31        23
# 2011-12-19    0.00        48        21
# 2011-12-20    0.02        48        40
# 2011-12-21    0.12        59        40
# 2011-12-22    0.06        60        48
# 2011-12-23    0.86        51        36
# 2011-12-24    0.00        37        27
# 2011-12-25    0.00        48        26
# 2011-12-26    0.00        48        33
# 2011-12-27    0.70        57        32
# 2011-12-28    0.00        50        32
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
# ...

# %%
weather = weather.fillna(method="ffill")

# %%
weather.apply(pd.isnull).sum()
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
# Check for missing value defined in data documentation
weather.apply(lambda x: (x == 9999).sum())
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
weather.dtypes
# Out:
# precip      float64
# temp_max      int64
# temp_min      int64
# dtype: object

# %%
weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2022-10-12', '2022-10-13', '2022-10-14', '2022-10-15', '2022-10-16',
#        '2022-10-17', '2022-10-18', '2022-10-19', '2022-10-20', '2022-10-21'],
#       dtype='object', name='DATE', length=19287)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2022-10-12', '2022-10-13', '2022-10-14', '2022-10-15',
#                '2022-10-16', '2022-10-17', '2022-10-18', '2022-10-19',
#                '2022-10-20', '2022-10-21'],
#               dtype='datetime64[ns]', name='DATE', length=19287, freq=None)

# %%
weather.index.year
# Out:
# Int64Index([1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970,
#             ...
#             2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022],
#            dtype='int64', name='DATE', length=19287)

# %%
weather[["temp_max", "temp_min"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather.index.year.value_counts().sort_index()
# Out:
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    294
# Name: DATE, dtype: int64

# %%
weather["precip"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather.groupby(weather.index.year).apply(lambda x: x["precip"].sum()).plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather["target"] = weather.shift(-1)["temp_max"]

# %%
weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1970-01-01    0.00        28        22    31.0
# 1970-01-02    0.00        31        22    38.0
# 1970-01-03    0.02        38        25    31.0
# 1970-01-04    0.00        31        23    35.0
# 1970-01-05    0.00        35        21    36.0
# ...            ...       ...       ...     ...
# 2022-10-17    0.08        67        54    58.0
# 2022-10-18    0.00        58        48    56.0
# 2022-10-19    0.00        56        43    61.0
# 2022-10-20    0.00        61        44    64.0
# 2022-10-21    0.00        64        43     NaN
#
# [19287 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
weather = weather.iloc[:-1,:].copy()

# %%
weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1970-01-01    0.00        28        22    31.0
# 1970-01-02    0.00        31        22    38.0
# 1970-01-03    0.02        38        25    31.0
# 1970-01-04    0.00        31        23    35.0
# 1970-01-05    0.00        35        21    36.0
# ...            ...       ...       ...     ...
# 2022-10-16    0.00        66        52    67.0
# 2022-10-17    0.08        67        54    58.0
# 2022-10-18    0.00        58        48    56.0
# 2022-10-19    0.00        56        43    61.0
# 2022-10-20    0.00        61        44    64.0
#
# [19286 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
predictors = ["precip", "temp_max", "temp_min"]

# %%
train = weather.loc[:"2020-12-31"]
test = weather.loc["2021-01-01":]

# %%
train
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1970-01-01    0.00        28        22    31.0
# 1970-01-02    0.00        31        22    38.0
# 1970-01-03    0.02        38        25    31.0
# 1970-01-04    0.00        31        23    35.0
# 1970-01-05    0.00        35        21    36.0
# ...            ...       ...       ...     ...
# 2020-12-27    0.00        38        24    51.0
# 2020-12-28    0.00        51        33    43.0
# 2020-12-29    0.00        43        28    43.0
# 2020-12-30    0.00        43        24    48.0
# 2020-12-31    0.36        48        35    40.0
#
# [18628 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
test
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 2021-01-01    0.63        40        30    53.0
# 2021-01-02    0.07        53        36    39.0
# 2021-01-03    0.12        39        33    45.0
# 2021-01-04    0.01        45        35    43.0
# 2021-01-05    0.00        43        36    43.0
# ...            ...       ...       ...     ...
# 2022-10-16    0.00        66        52    67.0
# 2022-10-17    0.08        67        54    58.0
# 2022-10-18    0.00        58        48    56.0
# 2022-10-19    0.00        56        43    61.0
# 2022-10-20    0.00        61        44    64.0
#
# [658 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(test["target"], predictions)
# Out:
# 45.875332483922385

# %%
combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
combined.columns = ["actual", "predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2021-01-01    53.0    42.249106
# 2021-01-02    39.0    51.939570
# 2021-01-03    45.0    44.028798
# 2021-01-04    43.0    47.906180
# 2021-01-05    43.0    47.537277
# ...            ...          ...
# 2022-10-16    67.0    66.146822
# 2022-10-17    58.0    67.523674
# 2022-10-18    56.0    60.482963
# 2022-10-19    61.0    56.999487
# 2022-10-20    64.0    59.764082
#
# [658 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# ...

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([-1.33059302,  0.44954353,  0.51687777])

# %%
weather["month_max"] = weather["temp_max"].rolling(30).mean()

weather["month_day_max"] = weather["month_max"] / weather["temp_max"]

weather["max_min"] = weather["temp_max"] / weather["temp_min"]

# %%
weather = weather.iloc[30:,:].copy()

# %%
def create_predictions(predictors, weather, reg):
    train = weather.loc[:"2020-12-31"]
    test = weather.loc["2021-01-01":]

    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])

    error = mean_squared_error(test["target"], predictions)

    combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["actual", "predictions"]
    return error, combined

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather["monthly_avg"] = weather["temp_max"].groupby(weather.index.month).apply(lambda x: x.expanding(1).mean())
weather["day_of_year_avg"] = weather["temp_max"].groupby(weather.index.day_of_year).apply(lambda x: x.expanding(1).mean())
# Out:
# <ipython-input-104-e53b44305d92>:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   weather["monthly_avg"] = weather["temp_max"].groupby(weather.index.month).apply(lambda x: x.expanding(1).mean())
# <ipython-input-104-e53b44305d92>:2: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# ...

# %%
reg.coef_
# Out:
# array([-1.33059302,  0.44954353,  0.51687777])

# %%
weather.corr()["target"]
# Out:
# precip            -0.004119
# temp_max           0.915040
# temp_min           0.915218
# target             1.000000
# month_max          0.871455
# month_day_max     -0.332539
# max_min           -0.304638
# monthly_avg        0.888947
# day_of_year_avg    0.901355
# Name: target, dtype: float64

# %%
combined["diff"] = (combined["actual"] - combined["predictions"]).abs()

# %%
combined.sort_values("diff", ascending=False).head(10)
# Out:
#             actual  predictions       diff
# DATE
# 2021-03-08    66.0    41.784287  24.215713
# 2022-02-23    35.0    58.708531  23.708531
# 2021-05-21    94.0    70.709592  23.290408
# 2022-05-20    87.0    66.843462  20.156538
# 2022-01-14    21.0    40.683197  19.683197
# 2022-06-16    94.0    74.660745  19.339255
# 2022-02-22    69.0    50.295796  18.704204
# 2021-05-01    79.0    60.528501  18.471499
# 2022-03-13    55.0    36.704640  18.295360
# 2022-03-05    62.0    43.784464  18.215536
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
# ...

# %%
# Next steps

* Predict weather for entire next week versus a single day
* Try data from multiple close-by weather stations over a region
* Use more of the predictors in the data file
* Create more predictors (ratios, daily averages, etc)
* Try different algorithms
* Setup backtesting to make predictions for all years (versus just 2021)
